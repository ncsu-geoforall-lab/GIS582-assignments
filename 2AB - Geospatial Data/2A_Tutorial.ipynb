# %% [markdown]
# # NCSU GIS 582: Geospatial Modeling and Analysis
#
# ## Tutorial: 2 - Geospatial Data Models and Visualization

# %% [markdown]
# ### Resources
#
# - [GRASS Manual](https://grass.osgeo.org/grass-devel/manuals/)
# - [GRASS Jupyter Introduction](https://grass.osgeo.org/grass-devel/manuals/jupyter_intro.html)
# - [GRASS Python API Introduction](https://grass.osgeo.org/grass-devel/manuals/python_intro.html)

# %% [markdown]
# ## Google Colab Setup
#
# This tutorial uses the new `grass.tools` Python API introduced in GRASS 8.5, so we install GRASS 8.5 from the conda-forge channel using [condacolab](https://github.com/conda-incubator/condacolab).
#
# > **Important: the next cell restarts the Colab runtime.** After you run it, Colab will report "Your session crashed for an unknown reason". This is expected and happens exactly once. Wait a few seconds for the runtime to reconnect, then continue with the next cell. If you use "Run all", run it again after the restart: the install cell detects the existing conda installation and returns immediately.

# %%
# !pip install -q condacolab
import condacolab

condacolab.install()

# %% [markdown]
# After the runtime restarts, verify that conda is ready and print the system description to know where we are.

# %%
import condacolab

condacolab.check()
# !lsb_release -a

# %% [markdown]
# Install GRASS 8.5 from the conda-forge channel with mamba. It might take a couple of minutes according to the resources available.

# %%
# !mamba install -y -q grass=8.5

# %% [markdown]
# Check that GRASS is installed by asking which version is there, and check which Python version is running.

# %%
# !grass --version

import sys

v = sys.version_info
print(f"We are using Python {v.major}.{v.minor}.{v.micro}")

# %% [markdown]
# ## GRASS Setup
#
# Import the Python standard libraries we need.

# %%
import subprocess
import os
from pathlib import Path

# %% [markdown]
# We are going to import the GRASS Python API (`grass.script`), the GRASS Jupyter package (`grass.jupyter`), and the new `grass.tools` API, but first, we need to find the path to those packages using the `--config python_path` command. The conda install puts the `grass` executable on the PATH, and the notebook kernel now runs the matching conda Python.
#
# We use `subprocess.check_output` to find the path and `sys.path.append` to add it to the path.

# %%
# Ask GRASS where its Python packages are.
sys.path.append(
    subprocess.check_output(["grass", "--config", "python_path"], text=True).strip()
)

# %%
# Import the GRASS packages we need.
import grass.script as gs
import grass.jupyter as gj
from grass.tools import Tools

# %% [markdown]
# Download and unzip the North Carolina basic sample dataset:
#
# > A complete list of available datasets can be found at: https://grass.osgeo.org/download/data/
#
# If you are running this tutorial locally, please change the path to where you have unzipped the sample dataset.

# %%
# !grass --tmp-project XY --exec g.download.project url=https://grass.osgeo.org/sampledata/north_carolina/nc_spm_08_grass7.tar.gz path=/content

# %% [markdown]
# Start a GRASS session using the sample dataset and create a `Tools` object. The `Tools` API (new in GRASS 8.5) exposes every GRASS tool as a Python function: for example, `tools.g_region(raster="elevation")` runs `g.region`. The API is marked experimental in 8.5 and becomes stable in 8.6. We will use it in the 3D visualization section.
#
# A session started from Python does not set up the addon search path the way the `grass` command does, so we also point the session at the user addon directory (`GRASS_ADDON_BASE`) and add it to `PATH`. This is what lets the addons we install next actually run. We also make sure PROJ and GDAL can find their data files in the conda install, which reprojection during import depends on.

# %%
# Point PROJ and GDAL at the conda data files. Colab presets PROJ_LIB and
# GDAL_DATA to the older system install in /usr/share, which crashes the
# newer conda PROJ, so these must be overridden, not just defaulted.
proj_data = Path(sys.prefix) / "local" / "share" / "proj"
gdal_data = Path(sys.prefix) / "local" / "share" / "gdal"
if proj_data.is_dir():
    os.environ["PROJ_DATA"] = str(proj_data)
    os.environ["PROJ_LIB"] = str(proj_data)
if gdal_data.is_dir():
    os.environ["GDAL_DATA"] = str(gdal_data)

# Start GRASS Session
session = gj.init(Path("nc_spm_08_grass7", "user1"))

# Make addons installed with g.extension visible to this session
addon_base = Path.home() / ".grass8" / "addons"
os.environ["GRASS_ADDON_BASE"] = str(addon_base)
os.environ["PATH"] = os.pathsep.join(
    [str(addon_base / "bin"), str(addon_base / "scripts"), os.environ["PATH"]]
)

# Run GRASS tools as Python functions (new in GRASS 8.5)
tools = Tools(session=session)

# %% [markdown]
# Finally, install the two GRASS addons used in this tutorial with `g.extension`:
#
# - [v.in.ags](https://grass.osgeo.org/grass-stable/manuals/addons/v.in.ags.html) imports vector data from ArcGIS feature services (no extra Python packages needed).
# - The [t.stac](https://grass.osgeo.org/grass-stable/manuals/addons/t.stac.html) suite searches and imports imagery from STAC APIs and needs the `pystac`, `pystac-client`, and `tqdm` Python packages, which we install first.
#
# Note: the t.stac install below copies the addon scripts into place directly instead of using `g.extension`. This is a temporary workaround for a build problem on Colab that is being fixed in the addon itself.

# %%
# t.stac Python dependencies (v.in.ags needs none beyond GRASS and GDAL)
# !pip install -q "pystac>=1.12" "pystac_client>=0.8" "tqdm>=4.67"
# !g.extension extension=v.in.ags

# TEMPORARY workaround: install t.stac by copying its scripts directly.
# g.extension compilation of t.stac currently fails on Colab; a fix is
# submitted upstream, after which this block becomes simply
# !g.extension extension=t.stac
import shutil
import stat
import tempfile

src = Path(tempfile.mkdtemp()) / "grass-addons"
subprocess.run(
    ["git", "clone", "-q", "--depth", "1", "--branch", "grass8",
     "--filter=blob:none", "--sparse", "https://github.com/OSGeo/grass-addons", str(src)],
    check=True,
)
subprocess.run(
    ["git", "-C", str(src), "sparse-checkout", "set", "src/temporal/t.stac"], check=True
)
tstac = src / "src" / "temporal" / "t.stac"
scripts_dir = addon_base / "scripts"
etc_dir = addon_base / "etc" / "t.stac"
scripts_dir.mkdir(parents=True, exist_ok=True)
etc_dir.mkdir(parents=True, exist_ok=True)
for tool in ("t.stac.catalog", "t.stac.collection", "t.stac.item"):
    dest = scripts_dir / tool
    shutil.copy(tstac / tool / f"{tool}.py", dest)
    dest.chmod(dest.stat().st_mode | stat.S_IEXEC)
shutil.copy(tstac / "libstac" / "staclib.py", etc_dir / "staclib.py")
print("t.stac installed")

# %%
# Check that the addons and their Python dependencies are ready
import pystac
import pystac_client
import tqdm

print(f"pystac {pystac.__version__}, pystac-client {pystac_client.__version__}")
# !v.in.ags --help
# !t.stac.item --help

# %% [markdown]
# Now that we have initialized the GRASS session, we can start using GRASS tools and functions.

# %% [markdown]
# ## 2A: Geospatial Data Models

# %% [markdown]
# ### 1. Resampling raster data to different resolutions
#
# Resample the given raster map to higher and lower resolution (30m->10m, 30m->100m) and compare resampling by nearest neighbor with bilinear and bicubic method.
#
# First, set the computation region extent to our study area and set resolution to 30 meters. The computational region (region for short) is set using g.region module, the -p flag is used to print the region coordinates and resolution. Here we use a predefined region which is included in our data set.

# %%
# !g.region region=swwake_30m -p

# %% [markdown]
# Then we display the 30m resolution NED elevation raster. To display raster maps in Jupyter Notebooks, we can use the `gj.Map` function from the `grass.jupyter` Python package.
#
# > By default, the map will be saved in the current working directory. You can specify a different path by providing the full path in the `filename` parameter. In Google Colab, we save the output images in the `/content` directory. However you can change it to any other directory you prefer or mount your Google Drive to save the outputs there by including teh following code at the beginning of the notebook:
#
# ```python
# from google.colab import drive
# drive.mount('/content/drive')
# ```
#
# For more information, please refer to [this guide](https://colab.research.google.com/notebooks/io.ipynb).

# %%
# Create Map instance
elev_ned_30m_map = gj.Map(filename="elev_ned_30m.png")
elev_ned_30m_map.d_rast(map="elev_ned_30m")

# Display map
elev_ned_30m_map.show()

# %% [markdown]
# To resample it to 10m resolution, first set the computational region to resolution 10m, then resample the raster using the nearest neighbor method.
#
# > How many new cells do you expect in the resampled raster compared to the original raster?

# %%
# !g.region res=10 -p
# !r.resamp.interp elev_ned_30m out=elev_ned10m_nn method=nearest

# %% [markdown]
# Now display the resampled map "elev_ned10m_nn" the same way we displayed the original map.

# %%
# Add you code below to display the resampled map elev_ned10m_nn

# %%
# @title Solution

# Create Map instance
m = gj.Map()
m.d_rast(map="elev_ned10m_nn")

# Display map
m.show()

# %% [markdown]
# The elevation map "elev_ned10m_nn" looks the same as the original one, so now check the resampled elevation surface using the aspect map:

# %%
# !r.slope.aspect elevation=elev_ned10m_nn aspect=aspect_ned10m_nn

# %% [markdown]
#  Display the aspect map derived from the resampled elevation map.

# %% [markdown]
# #### Map: Aspect Nearest Neighbor Interoplation

# %%
# Create Map instance
aspect_ned10m_nn_map = gj.Map(filename="aspect_nn.png")
aspect_ned10m_nn_map.d_rast(map="aspect_ned10m_nn")

# Display map
aspect_ned10m_nn_map.show()

# %% [markdown]
# Now, reinterpolate DEMs using bilinear and bicubic interpolation. Check the structure of interpolated elevation surfaces using aspect maps.

# %%
# !r.resamp.interp elev_ned_30m out=elev_ned10m_bil meth=bilinear
# !r.resamp.interp elev_ned_30m out=elev_ned10m_bic meth=bicubic
# !r.slope.aspect elevation=elev_ned10m_bil aspect=aspect_ned10m_bil
# !r.slope.aspect elevation=elev_ned10m_bic aspect=aspect_ned10m_bic

# %% [markdown]
# #### Map: Aspect Bilinear Interoplation

# %%
# Create Map instance
aspect_ned10m_bil_map = gj.Map(filename="aspect_bil.png")
aspect_ned10m_bil_map.d_rast(map="aspect_ned10m_bil")

# Display map
aspect_ned10m_bil_map.show()

# %% [markdown]
# #### Map: Aspect Bicubic Interoplation

# %%
# Create Map instance
aspect_ned10m_bic_map = gj.Map(filename="aspect_bic.png")
aspect_ned10m_bic_map.d_rast(map="aspect_ned10m_bic")

# Display map
aspect_ned10m_bic_map.show()

# %% [markdown]
# #### Question 1
#
# **Why is the aspect map of the elevation raster map computed with the nearest neighbor method different from the one computed by bilinear interpolation?**

# %% [markdown]
# Resample to lower resolution (30m -> 100m).

# %% [markdown]
# Now change the region's resolution and resample elevation (which is a continuous field) and land use (which has discrete categories).

# %%
# !g.region res=100 -p
# !r.resamp.stats elev_ned_30m out=elev_new100m_avg method=average

# %% [markdown]
# #### Map: Elevation 100m

# %%
# Create Map instance
elev_100m_map = gj.Map(filename="elev_100m.png")
elev_100m_map.d_rast(map="elev_new100m_avg")

# Display map
elev_100m_map.show()

# %% [markdown]
# Resample landuse to 100m resolution

# %%
# !r.resamp.stats landuse96_28m out=landuse96_100m method=mode

# %% [markdown]
# #### Map: Landuse 100m

# %%
# Create Map instance
landuse96_100m_map = gj.Map(filename="landuse96_100m.png")
landuse96_100m_map.d_rast(map="landuse96_100m")

# Display map
landuse96_100m_map.show()

# %% [markdown]
# #### Question 2
#
# **Explain selection of aggregation method. Can we use average also for landuse? What does mode mean?**

# %% [markdown]
# ### 2. Convert from vector to raster
#
# Now let's convert vector data to raster for use in raster-based analysis.
#
# Convert the polylines in the "streets" vector to raster. Set the resolution to 30m and use speed limit attribute.

# %%
# !g.region res=30 -p
# !v.to.rast streets_wake out=streets_speed_30m use=attr attrcol=SPEED type=line

# %% [markdown]
# #### Map: Vector to Raster

# %%
# Create Map instance
vect_to_rast_map = gj.Map(filename="vect_to_rast.png")

# Display raster data
vect_to_rast_map.d_rast(map="streets_speed_30m")

# Display raster legend
# vect_to_rast_map.d_legend(raster="streets_speed_30m", at=[5,30,2,5], use=[25,35,45,55,65] )
# Add legend
# Full documentation found at:
# https://grass.osgeo.org/grass-devel/manuals/d.legend.html
vect_to_rast_map.d_legend(
    raster="streets_speed_30m",
    at=[10, 45, 5, 12],
    fontsize=12,
    title="Speed Limit (mph)",
    title_fontsize=14,
    color="#000000",
    use=[25, 35, 45, 55, 65],
    flags="b",
)

# Add a scale bar and north arrow
# Full documentation found at:
# https://grass.osgeo.org/grass-devel/manuals/d.barscale.html
vect_to_rast_map.d_barscale(
    at=[2, 8],
    style="both_ticks",
    color="#000000",
    bgcolor="none",
    fontsize=14,
    flags="n",
)

# Display map
vect_to_rast_map.show()

# %% [markdown]
# ### 3. Convert from raster to vector data
#
# Let's convert DEM derived streams to vector lines. First, set the computational region to the streams raster map (`streams_derived`), then [thin](https://grass.osgeo.org/grass-devel/manuals/r.thin.html) the raster lines and convert to vector lines.

# %%
# !g.region raster=streams_derived -p
# !r.thin streams_derived output=streams_derived_t
# !r.to.vect streams_derived_t output=streams_derived_t type=line

# %% [markdown]
# #### Question 3
#
# **Explain why we are using the r.thin tool.**

# %% [markdown]
#  Visually compare the result with streams digitized from airphotos.

# %% [markdown]
# #### Map: Streams Compare

# %%
# Create Map instance
streams_compare_map = gj.Map(filename="streams_compare.png")

# Display vector data
streams_compare_map.d_vect(map="streams_derived_t", color="blue", fill_color=None, legend_label="Derived Streams")
streams_compare_map.d_vect(map="streams", color="red", legend_label="Digitized Streams")

# Display raster legend
streams_compare_map.d_legend_vect(at=[70,12], flags="b")

# Display map
streams_compare_map.show()

# %% [markdown]
# Convert raster areas representing basins to vector polygons.
#
# To convert, use raster values as category numbers (flag -v) and display boundaries of vector polygons.
# Verify the basin boundaries by displaying them together with streams - the stream networks should "fit" within the basin boundaries.

# %%
# !g.region raster=basin_50K -p
# !r.to.vect -sv basin_50K output=basin_50Kval type=area

# %% [markdown]
# #### Map: Basins

# %%
# Create Map instance
basins_map = gj.Map(filename="basins.png")

# Display raster data
basins_map.d_rast(map="basin_50K")

# Display vector data
basins_map.d_vect(map="basin_50Kval", type="boundary", width=2)
basins_map.d_vect(map="streams", color="blue")

# Display map
basins_map.show()

# %% [markdown]
# ### 4. Import vector data from a web service
#
# So far we have worked with data already stored in our GRASS project. Many agencies publish live vector layers through web services instead of files. [NC OneMap](https://www.nconemap.gov/) publishes authoritative statewide layers through ArcGIS feature services, a REST API that serves features on request.
#
# The `v.in.ags` addon (installed during setup) downloads features from an ArcGIS FeatureServer or MapServer layer and imports them as a GRASS vector map, reprojecting them to the project coordinate reference system automatically.
#
# First, list the layers the education service offers with the `-l` flag:

# %%
# !v.in.ags -l url=https://services.nconemap.gov/secure/rest/services/NC1Map_Education/FeatureServer format=plain

# %% [markdown]
# Layer 3 contains public school locations for the whole state. We only need our study area, so we set the computational region and use `extent=region` to clip the output. The `where=`, `fields=`, and `bbox_filter=` options can further reduce what is downloaded from the server.

# %%
# !g.region region=swwake_30m -p
# !v.in.ags url=https://services.nconemap.gov/secure/rest/services/NC1Map_Education/FeatureServer/3 output=schools_nc extent=region
# !v.info map=schools_nc

# %% [markdown]
# #### Map: Imported web service features

# %%
# Create Map instance
schools_map = gj.Map(filename="schools_webservice.png")

# Display shaded elevation as the base layer
schools_map.d_rast(map="elevation_shade")

# Display vector data
schools_map.d_vect(map="roadsmajor", color="grey", legend_label="Major Roads")
schools_map.d_vect(
    map="schools_nc",
    icon="basic/circle",
    size=8,
    fill_color="yellow",
    color="black",
    legend_label="Public Schools",
)
schools_map.d_legend_vect(at=[65, 12], flags="b")

# Display map
schools_map.show()

# %% [markdown]
# #### Question 4
#
# What are the advantages and limitations of importing data directly from a web service compared to downloading and storing a file? The service publishes data in a different coordinate reference system than our project. How was that handled during import?

# %% [markdown]
# ### 5. Search and import satellite imagery with STAC
#
# The [SpatioTemporal Asset Catalog (STAC)](https://stacspec.org/) specification is a standard way to describe and search collections of satellite imagery and other geospatial data. A STAC API organizes data as:
#
# - **Catalog**: the entry point that groups collections
# - **Collection**: a dataset, for example Sentinel-2 Level 2A
# - **Item**: one observation, for example a single Sentinel-2 scene
# - **Asset**: one file belonging to an item, for example the red band as a cloud optimized GeoTIFF (COG)
#
# We use the public [Earth Search](https://element84.com/earth-search/) API, which requires no account and serves COGs stored on AWS. The `t.stac` addon suite explores catalogs (`t.stac.catalog`), collections (`t.stac.collection`), and searches and imports items (`t.stac.item`).
#
# First, see which collections the catalog offers:

# %%
# !t.stac.catalog url=https://earth-search.aws.element84.com/v1 format=plain -b

# %% [markdown]
# Look at the metadata of the Sentinel-2 Level 2A collection:

# %%
# !t.stac.collection url=https://earth-search.aws.element84.com/v1 collection_id=sentinel-2-l2a format=plain -b

# %% [markdown]
# Now search for Sentinel-2 items over our study area. When `bbox` is not given, `t.stac.item` uses the current computational region converted to WGS84, so we set the region to the `elevation` raster first. We filter to June 2024 with less than 10 percent cloud cover and print a summary of the matching items with the `-m` flag.

# %%
# !g.region raster=elevation -p
# !t.stac.item url=https://earth-search.aws.element84.com/v1 collection_id=sentinel-2-l2a datetime=2024-06-01/2024-06-30 query='{"eo:cloud_cover":{"lt":10}}' format=plain -m

# %% [markdown]
# Pick one item id from the summary and import just the red, green, and blue band assets, clipped to the computational region at the region resolution. We use `S2A_17SQV_20240611_0_L2A`, a nearly cloud free scene that covers the whole study area; you can substitute another id from your own search. The download pulls three whole band COGs, so this takes a few minutes.

# %%
# !t.stac.item url=https://earth-search.aws.element84.com/v1 collection_id=sentinel-2-l2a ids=S2A_17SQV_20240611_0_L2A asset_keys=red,green,blue extent=region resolution=region method=bilinear nprocs=3 memory=2000 -d

# %% [markdown]
# The imported rasters are named `collection.item.asset`. Find them, enhance the color balance for display, and render an RGB composite.

# %%
# Find the imported band rasters
rasters = gs.list_strings(type="raster", pattern="sentinel-2-l2a*", mapset=".")
red = [r for r in rasters if ".red@" in r][0]
green = [r for r in rasters if ".green@" in r][0]
blue = [r for r in rasters if ".blue@" in r][0]
print(red, green, blue)

# Enhance the color balance of the composite
gs.run_command("i.colors.enhance", red=red, green=green, blue=blue, strength=95)

# Create Map instance
s2_map = gj.Map(filename="sentinel2_rgb.png")
s2_map.d_rgb(red=red, green=green, blue=blue)
s2_map.d_vect(map="roadsmajor", color="yellow")
s2_map.show()

# %% [markdown]
# #### Question 5
#
# In STAC terms, what is the difference between a collection, an item, and an asset? Why does it matter that the imagery is stored as cloud optimized GeoTIFFs when we import only our study region?

# %% [markdown]
# ## 2B: Data display and visualization

# %% [markdown]
# #### Changing the default font
#
# Change the default font used for when rendering a 2D map by setting the font with `gj.Map(font="Font_Name")` or set the font independently for individual map elements like raster, vector, legend, etc.

# %% [markdown]
# ### 1. Basic 2D display operations
#
# Visualy explore relation between developed areas and topography. Set the region and display land use categories 1, 2 (developed land) over shaded topography.

# %% [markdown]
# Set the computational region to landuse map.

# %%
# !g.region raster=landuse96_28m -p

# %% [markdown]
# #### Map: Developed Area

# %%
# Create Map instance
landuse_elev_map = gj.Map(filename="mylandsat.png")

landuse_elev_map.d_rgb(red="lsat7_2002_30", green="lsat7_2002_20", blue="lsat7_2002_10")

landuse_elev_map.d_rast(
    map="landuse96_28m",
    values=[1,2]
)

# Add Major Roads
landuse_elev_map.d_vect(map="roadsmajor", color="yellow")

# Display map
landuse_elev_map.show()

# %% [markdown]
# #### Question 1
#
# **How did the developed area change between 1996 and 2002?**

# %% [markdown]
# ### 2. Change colors for raster maps
#
# There are many ways how to adjust or create custom color ramps for raster maps, see [r.colors](https://grass.osgeo.org/grass-devel/manuals/r.colors.html) manual, we explore only some basic tools here.
#
# Compare the use of equal interval and histogram equalized color table for slope
#
# First, we will create our copy of the slope map.

# %%
# !g.copy raster=slope,myslope

# %% [markdown]
# Now display it with an equal interval color ramp with colors ranging from blue-green-yellow to red (bgyr).

# %%
# !r.colors myslope color=bgyr

# %% [markdown]
# #### Map: Slope Equal Interval Color Ramp

# %%
# Create Map instance
myslope_map = gj.Map(filename="myslopecolor.png")

# Display raster data
myslope_map.d_rast(map="myslope")

# Add Legend
myslope_map.d_legend(
    raster="myslope",
    at=[10, 45, 5, 12],
    fontsize=12,
    title="Slope (degrees)",
    title_fontsize=14,
    color="#000000",
    flags="b"
)

# Display map
myslope_map.show()

# %% [markdown]
# Change to the histogram equalized color table, and save the new slope map.

# %%
# !r.colors -e myslope color=bgyr

# %%
# Create Map instance
myslope_map = gj.Map(filename="myslopecolorequalized.png")

# Display raster data
myslope_map.d_rast(map="myslope")

# Add Legend
myslope_map.d_legend(
    raster="myslope",
    at=[10, 45, 5, 12],
    fontsize=12,
    title="Slope (degrees)",
    title_fontsize=14,
    color="#000000",
    flags="b",
)

# Display map
myslope_map.show()

# %% [markdown]
# To explain the difference between the two maps, you can generate a histogram.

# %% [markdown]
# #### Histogram: Slope Color Histogram Equalized

# %%
slopehistogram = gj.Map(filename="slopehistogram.png")
slopehistogram.d_histogram(map="myslope")
slopehistogram.show()

# %% [markdown]
# #### Question 2
#
# **What is the effect of the histogram equalized color table on the slope map pattern?**

# %% [markdown]
# ### 3. Modify legend, scale and grid

# %% [markdown]
# To re-size the legend for myslope you need to update the `at` parameter of `d.legend`.
#
# ```python
# myslope_map.d_legend(
#     raster="myslope",
#     at=[10, 45, 5, 12],
#     fontsize=12,
#     title="Slope (degrees)",
#     title_fontsize=14,
#     color="#000000",
#     flags="b",
# )
# ```
#
# The numbers are bottom,top,left,right as percentage of screen coordinates.

# %% [markdown]
# #### Task: Update Slope Map Components
#
# 1. Add units to the [legend](https://grass.osgeo.org/grass-devel/manuals/d.legend.html)
# 2. Add [barscale](https://grass.osgeo.org/grass-devel/manuals/d.barscale.html) and change its length and units.
#
# > Note: you can use horizontal legends by using Placement at=6,10,2,30

# %%
# @title Solution to Task: Update Slope Map Components

# Create Map instance
myslope_map = gj.Map()

# Display raster data
myslope_map.d_rast(map="myslope")
myslope_map.d_barscale(length=1000)
myslope_map.d_legend(raster="myslope", at=[6,10,20,50])

# Display map
myslope_map.show()

# %% [markdown]
# Add grid for state plane coordinates at 5000m with ticks at 1000m. Also add a lat/long grid at 2 arc minute interval.

# %% [markdown]
# #### Map: Grid for state plane coordinates at 5000m with ticks at 1000m.

# %%
# Create Map instance
myslope_map = gj.Map(filename="myslopemap_gridxy.png")

# Display raster data
myslope_map.d_rast(map="myslope")
myslope_map.d_grid(size=5000, color="brown")
myslope_map.d_grid(size=1000, flags="n")
myslope_map.d_barscale(at=[2,8], style="both_ticks", color="#000000", bgcolor="none", fontsize=14, flags="n")
myslope_map.d_legend(
    raster="myslope",
    at=[10, 45, 5, 12],
    fontsize=12,
    title="Slope (degrees)",
    title_fontsize=14,
    color="#000000",
    flags="b",
)

# Display map
myslope_map.show()

# %% [markdown]
# #### Map: Grid lat/long grid at 2 arc minute interval

# %%
# Create Map instance
myslope_map = gj.Map(filename="myslopemap_gridlatlong.png")

# Display raster data
myslope_map.d_rast(map="myslope")
myslope_map.d_grid(size="0:02", color="black", flags="g")
myslope_map.d_barscale(
    at=[2, 8],
    style="both_ticks",
    color="#000000",
    bgcolor="none",
    fontsize=14,
    flags="n",
)
myslope_map.d_legend(
    raster="myslope",
    at=[10, 45, 5, 12],
    fontsize=12,
    title="Slope (degrees)",
    title_fontsize=14,
    color="#000000",
    flags="b",
)

# Display map
myslope_map.show()

# %% [markdown]
# ### 4. Visualization in 3D perspective
#
# GRASS ships a native 3D renderer available in Jupyter as `gj.Map3D` (built on [m.nviz.image](https://grass.osgeo.org/grass-stable/manuals/m.nviz.image.html)). It does not work in Google Colab, but you can run it locally:
#
# ```python
# elevation_3dmap = gj.Map3D(filename="3dElevation.png")
# elevation_3dmap.render(
#     elevation_map="elevation",
#     color_map="elevation",
#     perspective=20,
#     height=3000,
#     vline="streams",
#     vline_color="blue",
#     fringe=["ne", "nw", "sw", "se"],
#     arrow_position=[100, 50],
# )
# elevation_3dmap.overlay.d_legend(raster="elevation", at=(60, 97, 87, 92))
# elevation_3dmap.show()
# ```
#
# In Colab we take a different approach that works anywhere: read GRASS rasters as NumPy arrays and build interactive 3D scenes with [PyVista](https://docs.pyvista.org/). No intermediate files are needed, and we use the `tools` object from the setup section to run the GRASS steps.
#
# First install PyVista and its rendering dependencies: a virtual display and the Mesa OpenGL libraries. The interactive `html` backend renders in your browser, but VTK still needs a display to build the scene.

# %%
# !apt-get install -y -qq xvfb libgl1 libglx-mesa0 libgl1-mesa-dri
# !pip install -q 'pyvista[all]' trame trame-vtk trame-vuetify

# %%
import numpy as np
import pyvista as pv
import grass.script.array as garray

# pv.start_xvfb()
pv.set_jupyter_backend("html")
pv.global_theme.notebook = True

# %% [markdown]
# #### Single surface
#
# Set the region to the `elevation` raster and read it as a NumPy array with `grass.script.array`. Cells with no data become NaN. We also rasterize the `streams` vector so we can drape it over the surface.

# %%
# Set the region to the elevation raster
print(tools.g_region(raster="elevation", flags="p").text)
region = gs.parse_command("g.region", flags="g")
rows, cols = int(region["rows"]), int(region["cols"])

# Read the elevation raster as a NumPy array (nulls become NaN)
elev = np.array(garray.array(mapname="elevation", null=np.nan))

# Rasterize the streams vector and read it the same way
tools.v_to_rast(input="streams", output="streams_rast", type="line", use="val", value=1)
streams = np.array(garray.array(mapname="streams_rast", null=np.nan, dtype=np.float64))

# Build coordinate grids from the region bounds
x = np.linspace(float(region["w"]), float(region["e"]), cols)
y = np.linspace(float(region["n"]), float(region["s"]), rows)
xx, yy = np.meshgrid(x, y)

# %% [markdown]
# Build a surface mesh from the coordinate grids and the elevation array, and add the stream cells as points floating just above the surface. The scene is interactive: drag to rotate, scroll to zoom.

# %%
surface = pv.StructuredGrid(xx, yy, elev)

# Streams as points floating just above the surface
sy, sx = np.where(~np.isnan(streams) & ~np.isnan(elev))
stream_points = np.column_stack([xx[sy, sx], yy[sy, sx], elev[sy, sx] + 2])

pl = pv.Plotter()
pl.add_mesh(
    surface,
    scalars=surface.points[:, 2],
    cmap="terrain",
    smooth_shading=True,
    scalar_bar_args={"title": "Elevation (m)"},
)
pl.add_mesh(
    pv.PolyData(stream_points), color="blue", point_size=3, render_points_as_spheres=True
)
pl.set_scale(zscale=3)
pl.show()

# %% [markdown]
# #### Draping other data over the surface
#
# Any raster covering the region can be draped over the surface as colors. The `grass.tools` API can even return a computed raster directly as a NumPy array: pass `np.ndarray` as the value of an output parameter. Here we compute shaded relief without ever naming an output raster, and drape the land use map read with `grass.script.array`.

# %%
# grass.tools returns the computed raster as a NumPy array
shade = tools.r_relief(input="elevation", output=np.ndarray)
print(f"r.relief returned an array with shape {shade.shape}")

# Attach rasters as point data on the surface mesh
landuse = np.array(garray.array(mapname="landuse96_28m", null=np.nan, dtype=np.float64))
surface["Shaded Relief"] = np.asarray(shade).ravel(order="F")
surface["Land Use"] = landuse.ravel(order="F")

pl = pv.Plotter()
pl.add_mesh(surface, scalars="Land Use", cmap="tab20", smooth_shading=True)
pl.set_scale(zscale=3)
pl.show()

# %% [markdown]
# Try switching `scalars="Land Use"` to `scalars="Shaded Relief"` with `cmap="gray"` to see the relief shading draped over the surface instead.

# %% [markdown]
# #### Multiple surfaces with cross sections
#
# Lidar surveys measure both the bare ground and the tops of vegetation and buildings. Here we compare two surfaces for a small rural subregion: the bare earth DEM `elev_lid792_1m` and a surface interpolated from multiple return lidar points, which includes vegetation and structures. In the GRASS desktop GUI this comparison is done with interactive cutting planes in the 3D view; here PyVista clip and slice filters play that role.
#
# Set the region to the saved `rural_1m` region and interpolate the multiple return surface with `v.surf.rst` (interpolation is covered in detail later in the course). This takes a minute or two.

# %%
print(tools.g_region(region="rural_1m", flags="p").text)
tools.v_surf_rst(
    input="elev_lidrural_mrpts",
    elevation="elev_lidruralmr_1m",
    npmin=120,
    segmax=25,
    tension=40,
    smooth=1.0,
)

# %% [markdown]
# Read both surfaces as arrays, build a mesh for each, and build a volume that fills the space between them. Coloring the fill volume by the bare earth elevation makes the cross sections easier to read.

# %%
region = gs.parse_command("g.region", flags="g")
rows, cols = int(region["rows"]), int(region["cols"])
x = np.linspace(float(region["w"]), float(region["e"]), cols)
y = np.linspace(float(region["n"]), float(region["s"]), rows)
xx, yy = np.meshgrid(x, y)

# Bare earth DEM and the interpolated multiple return surface
be = np.array(garray.array(mapname="elev_lid792_1m", null=np.nan))
mr = np.array(garray.array(mapname="elev_lidruralmr_1m", null=np.nan))

be_grid = pv.StructuredGrid(xx, yy, be)
mr_grid = pv.StructuredGrid(xx, yy, mr)

# Volume between the two surfaces, colored by the bare earth elevation
xx3d = np.stack([xx, xx], axis=-1)
yy3d = np.stack([yy, yy], axis=-1)
zz3d = np.stack([be, mr], axis=-1)
fill = pv.StructuredGrid(xx3d, yy3d, zz3d)
fill["Bare Earth Elevation (m)"] = np.concatenate([be.ravel(order="F"), be.ravel(order="F")])

# %% [markdown]
# Clip away half of the volume to expose a cross section, with the bare earth surface for reference and the multiple return surface as a wireframe. The gap between the wireframe and the colored volume shows vegetation and buildings.

# %%
center = fill.center

pl = pv.Plotter()
# Clip away half of the volume to expose a cutting plane
pl.add_mesh(
    fill.clip(normal="x", origin=center),
    scalars="Bare Earth Elevation (m)",
    cmap="terrain",
)
# Bare earth surface for reference
pl.add_mesh(be_grid.clip(normal="x", origin=center), color="tan", opacity=0.4)
# Multiple return surface as a wireframe on top
pl.add_mesh(
    mr_grid.clip(normal="x", origin=center),
    color="green",
    style="wireframe",
    line_width=0.5,
    opacity=0.3,
)
pl.set_scale(zscale=2)
pl.show(auto_close=False)
pl.screenshot("surfaces_crosssection.png")

# %% [markdown]
# #### Task: Explore the cross sections
#
# Change the clip `normal` to `"y"`, move the `origin`, or create a series of cutting planes with `fill.slice_along_axis(n=6, axis="y")`. Where do the two surfaces differ the most, and what land cover explains the difference? Save at least one image for your report: the `pl.screenshot("name.png")` call writes a PNG you can download from the Colab file browser.
