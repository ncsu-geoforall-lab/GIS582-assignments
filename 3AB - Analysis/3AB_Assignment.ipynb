# %% [markdown]
# <a href="https://colab.research.google.com/github/ncsu-geoforall-lab/GIS582-assignments/blob/main/3AB%20-%20Analysis/3AB_Assignment.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Assignment 3AB: Geospatial Analysis
#
# **Course:** [GIS 582 - Geospatial Modeling and Analysis](https://ncsu-geoforall-lab.github.io/geospatial-modeling-course/index.html)
# **Institution:** [NC State University, Center for Geospatial Analytics](https://cnr.ncsu.edu/geospatial/)
# **Instructors:** Helena Mitasova, Corey White, and team

# %% [markdown]
# ---
# ## Exercises
#
# Now it's your turn! Try these exercises to practice what you've learned.
#
# ### Exercise 1: Advanced Neighborhood Analysis
#
# **Task:** Calculate the **diversity** (number of different values) of land cover types in a 5x5 neighborhood.
#
# **Hint:** Use `r.neighbors` with `method=diversity` on the `landcover96_28m@PERMANENT` map.

# %%
# Your code for Exercise 1 here
# gs.run_command('r.neighbors', ...)

# %% [markdown]
# ### Exercise 2: Zonal Statistics by Landuse
#
# **Task:** Calculate the average slope for each land use category.
#
# **Hint:** Use `r.stats.zonal` with `base=landuse96_28m@PERMANENT` and `cover=slope`

# %%
# Your code for Exercise 2 here
# gs.run_command('r.stats.zonal', ...)

# %% [markdown]
# ### Exercise 3: Site Selection Using Map Algebra
#
# **Task:** Find suitable locations for a solar farm based on:
# - South-facing slopes (aspect between 135° and 225°)
# - Slope less than 5 degrees
# - More than 200m from roads (to reduce visual impact)
#
# **Hint:** Use `r.mapcalc` with conditional statements (&&, ||) and the `distance_to_roads` layer.

# %%
# Your code for Exercise 3 here
# expression = "solar_suitable = if(...)"
# gs.mapcalc(expression, overwrite=True)

# %% [markdown]
# ### Exercise 4: Multi-Factor Cost Surface
#
# **Task:** Create a cost surface that considers both slope AND land cover. Assume:
# - Forests have cost multiplier of 2.0
# - Developed areas have cost multiplier of 0.5
# - Other areas have cost multiplier of 1.0
#
# **Hint:** Create separate reclassified maps, then combine with `r.mapcalc`

# %%
# Your code for Exercise 4 here
# Step 1: Reclassify landcover
# Step 2: Combine with slope cost

# %% [markdown]
# ### Bonus Challenge: Evacuation Route Planning
#
# **Task:** Identify the optimal evacuation routes from all schools in Wake County to the nearest hospital, considering terrain difficulty.
#
# **Steps:**
# 1. Use `schools_wake@PERMANENT` and `hospitals@PERMANENT` vector layers
# 2. Create a cost surface based on slope
# 3. Calculate least cost paths from each school to nearest hospital
# 4. Visualize all paths on a single map

# %%
# Your code for Bonus Challenge here
